# %%
# !unzip /content/Pothole.dataset.yolov11.zip
# Out:
# Archive:  /content/Pothole.dataset.yolov11.zip
# replace Pothole.v1-raw.yolov11/data.yaml? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
pip install ultralytics

# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLO11n model
model = YOLO("yolo11n.pt")
# Out:
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 15.0MB/s]

# %%
import yaml
import os
import random
import cv2
import matplotlib.pyplot as plt
dir_images = "/content/Pothole.v1-raw.yolov11/train/images"
dir_labels = "/content/Pothole.v1-raw.yolov11/train/labels"
image_files = os.listdir(dir_images)

# Choose 16 random image files from the list
random_images = random.sample(image_files, 4)

# %%
final_model = model.train(data="/content/Pothole.v1-raw.yolov11/data.yaml", epochs=30, imgsz=640, batch=16, lr0=0.00001, dropout=0.15)
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# prompt: write a code to validate the model

from ultralytics import YOLO
import os

# Assuming 'final_model' from the previous code is available
# If not, load the trained model:
final_model = YOLO("/content/runs/detect/train6/weights/best.pt") # Replace with the actual path

# Define the validation dataset path
val_data_yaml = "/content/Pothole.v1-raw.yolov11/data.yaml" # Replace with the actual path to your validation YAML

# Perform validation
results = final_model.val(data=val_data_yaml)

# Print the validation results
results
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /content/Pothole.v1-raw.yolov11/valid/labels.cache... 133 images, 0 backgrounds, 0 corrupt: 100%|██████████| 133/133 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 9/9 [00:32<00:00,  3.57s/it]
#                    all        133        330      0.345      0.164      0.122     0.0347
# Speed: 2.9ms preprocess, 227.4ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to runs/detect/val
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7f0f96215750>
# ...

# %%
# prompt: write code for giving a img to validate odel

# Assuming 'final_model' from the previous code is available
# If not, load the trained model:
final_model = YOLO("/content/runs/detect/train6/weights/best.pt") # Replace with the actual path

# Define the path to the image you want to validate
image_path = "/content/Pothole.v1-raw.yolov11/train/images" # Replace with the actual path

# Perform inference on the image
results = final_model(image_path)

# Print the results
results

# Visualize the results (optional)
results[0].plot()
plt.show()
# Out:
# image 1/465 /content/Pothole.v1-raw.yolov11/train/images/img-100_jpg.rf.233751cac3399aa80b5e58a2afbb753a.jpg: 640x640 1 pothole, 266.1ms
# image 2/465 /content/Pothole.v1-raw.yolov11/train/images/img-101_jpg.rf.f213d98946c4f8858a5bf3200c89e39c.jpg: 640x640 1 pothole, 215.9ms
# image 3/465 /content/Pothole.v1-raw.yolov11/train/images/img-102_jpg.rf.16c56ff8f761aec963d9b57aa1b2d3fd.jpg: 640x640 1 pothole, 231.0ms
# image 4/465 /content/Pothole.v1-raw.yolov11/train/images/img-103_jpg.rf.09abf1a8e3477718e143255af3534d29.jpg: 640x640 1 pothole, 215.1ms
# image 5/465 /content/Pothole.v1-raw.yolov11/train/images/img-108_jpg.rf.a35e86abc558a98f252bfc10e49fd6d9.jpg: 640x640 2 potholes, 225.8ms
# image 6/465 /content/Pothole.v1-raw.yolov11/train/images/img-109_jpg.rf.add373710d0d425bd9340c33878e7d42.jpg: 640x640 1 pothole, 233.1ms
# image 7/465 /content/Pothole.v1-raw.yolov11/train/images/img-10_jpg.rf.eaceaaa6f119cf6eb49edc1bc92efaa2.jpg: 640x640 1 pothole, 247.8ms
# ...

# %%
final_model.export(format="onnx")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-864539b0ab04> in <cell line: 1>()
# ----> 1 final_model.export(format="onnx")
#
# NameError: name 'final_model' is not defined

# %%
# Assuming 'final_model' from the previous code is available
# If not, load the trained model:
from ultralytics import YOLO
final_model = YOLO("/content/runs/detect/train6/weights/best.pt") # Replace with the actual path

#Export the model
final_model.export(format="onnx")
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from '/content/runs/detect/train6/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (5.2 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.44...
# ONNX: export success ✅ 2.4s, saved as '/content/runs/detect/train6/weights/best.onnx' (10.1 MB)
#
# Export complete (3.3s)
# Results saved to /content/runs/detect/train6/weights
# Predict:         yolo predict task=detect model=/content/runs/detect/train6/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=/content/runs/detect/train6/weights/best.onnx imgsz=640 data=/content/Pothole.v1-raw.yolov11/data.yaml
# Visualize:       https://netron.app
# '/content/runs/detect/train6/weights/best.onnx'

# %%
# prompt: write code for download weights of dataset

from google.colab import files
files.download("/content/runs/detect/train6/weights/best.pt")
